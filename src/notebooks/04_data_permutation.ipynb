# %%
import os

import torch
from torch import nn

from src.utils.global_constants import MODELS_DIR
from src.utils.datasets import EmbeddingDataset
from src.nn_modules.mlp import BaselineMLP
from src.nn_modules.kan import BaselineKAN
from src.utils.train_test import train_data_permutation

# The random seed is fixed to ensure reproducibility of results
# torch.manual_seed(44)
device = (
    torch.accelerator.current_accelerator()
    if torch.accelerator.is_available()
    else torch.device("cpu")
)
device
# Out:
# device(type='cpu')

# %%
# Create a directory for trained models if it doesn't exist
os.makedirs(MODELS_DIR, exist_ok=True)

# %% [markdown]
# #### Datasets and training parameters

# %%
# Offline training parameters
learning_rate = 8e-4
batch_size = 256
criterion = nn.CrossEntropyLoss()
num_epochs = 100
early_stopping = 10
# Number of study sessions to perform with different feature vectors permutations
num_sessions = 4

# Precomputed elmbeddings of images from the CUB200 dataset generated by ResNet50 model
trainset = EmbeddingDataset("cub200_train_embed.pt")
testset = EmbeddingDataset("cub200_test_embed.pt")

# %% [markdown]
# #### Models definition

# %% [markdown]
# ###### MLP:

# %%
mlp = BaselineMLP()
mlp_optimizer = torch.optim.NAdam(mlp.parameters(), lr=learning_rate)
mlp
# Out:
# BaselineMLP(
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=400, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=400, out_features=200, bias=True)
#   )
# )

# %% [markdown]
# ###### KAN:

# %%
kan = BaselineKAN()
kan_optimizer = torch.optim.NAdam(kan.parameters(), lr=learning_rate)
kan
# Out:
# BaselineKAN(
#   (classifier): KANLayer(
#     (bn): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %% [markdown]
# #### Data Permutation Experiment

# %% [markdown]
# ###### MLP:

# %%
train_data_permutation(
    model=mlp,
    trainset=trainset,
    testset=testset,
    criterion=criterion,
    optimizer=mlp_optimizer,
    save_path="dp_mlp.pth",
    num_sessions=num_sessions,
    batch_size=batch_size,
    num_epochs=num_epochs,
    early_stopping=early_stopping,
    device=device,
)
# Out:
# The model's weights are saved to /home/trxxxxkov/projects/spbu-bachelor-thesis/src/models/dp_mlp.pth

# %% [markdown]
# ###### KAN:

# %%
train_data_permutation(
    model=kan,
    trainset=trainset,
    testset=testset,
    criterion=criterion,
    optimizer=kan_optimizer,
    save_path="dp_kan.pth",
    num_sessions=num_sessions,
    batch_size=batch_size,
    num_epochs=num_epochs,
    early_stopping=early_stopping,
    device=device,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 train_data_permutation(
#       2     model=kan,
#       3     trainset=trainset,
#       4     testset=testset,
#       5     criterion=criterion,
#       6     optimizer=kan_optimizer,
#       7     save_path="dp_kan.pth",
#       8     num_sessions=num_sessions,
#       9     batch_size=batch_size,
#      10     num_epochs=num_epochs,
#      11     early_stopping=early_stopping,
#      12     device=device,
#      13 )
#
# File ~/projects/spbu-bachelor-thesis/src/utils/train_test.py:259, in train_data_permutation(model, trainset, testset, criterion, optimizer, save_path, num_sessions, batch_size, num_epochs, early_stopping, device)
#     255 trainloader = DataLoader(
#     256     trainset, batch_size=batch_size, num_workers=2, shuffle=True
#     257 )
#     258 testloader = DataLoader(testset, batch_size=batch_size, num_workers=2)
# --> 259 _train(
#     260     model,
#     261     trainloader,
#     262     testloader,
#     263     criterion,
#     264     optimizer,
#     265     num_epochs,
#     266     early_stopping,
#     267     device=device,
#     268 )
#     269 logs.append({})
#     270 logs[-1]["test_loss"], preds, targets = _test_loop(
#     271     model, testloader, criterion, device
#     272 )
#
# File ~/projects/spbu-bachelor-thesis/src/utils/train_test.py:319, in _train(model, trainloader, testloader, criterion, optimizer, num_epochs, early_stopping, allowed_labels, metric, device)
#     317 early_stopping_patience = early_stopping
#     318 for _ in range(num_epochs):
# --> 319     logs = _epoch_loop(model, criterion, optimizer, trainloader, testloader, device)
#     320     curr_metric = metric(logs["preds"], logs["targets"], allowed_labels)
#     321     if metric.set_new_best(curr_metric):
#
# File ~/projects/spbu-bachelor-thesis/src/utils/train_test.py:352, in _epoch_loop(model, criterion, optimizer, trainloader, testloader, device, train, test)
#     348     logs["train_loss"] = _train_loop(
#     349         model, trainloader, criterion, optimizer, device
#     350     )
#     351 if test:
# --> 352     logs["test_loss"], logs["preds"], logs["targets"] = _test_loop(
#     353         model, testloader, criterion, device
#     354     )
#     355 return logs
#
# File ~/projects/spbu-bachelor-thesis/src/utils/train_test.py:395, in _test_loop(model, dataloader, criterion, device)
#     393 batch_inputs = batch_inputs.to(device)
#     394 batch_targets = batch_targets.to(device)
# --> 395 batch_outputs = model(batch_inputs)
#     396 if criterion is not None:
#     397     batch_loss = criterion(batch_outputs, batch_targets)
#
# File ~/projects/spbu-bachelor-thesis/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/projects/spbu-bachelor-thesis/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/projects/spbu-bachelor-thesis/src/nn_modules/kan.py:158, in BaselineKAN.forward(self, x)
#     157 def forward(self, x: torch.Tensor):
# --> 158     return self.classifier(x)
#
# File ~/projects/spbu-bachelor-thesis/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/projects/spbu-bachelor-thesis/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/projects/spbu-bachelor-thesis/src/nn_modules/kan.py:135, in KANLayer.forward(self, x)
#     132 # Normalize and clip input vales to fit in the fixed spline grids' range
#     133 x = torch.clip(self.bn(x), self.grid[self.spline_order], self.grid[-1])
#     134 output = F.linear(  # pylint: disable=E1102
# --> 135     self._bsplines_values_at(x).view(x.shape[0], -1),
#     136     self.bspline_coeffs.view(self.out_features, -1),
#     137 )
#     138 return output
#
# File ~/projects/spbu-bachelor-thesis/src/nn_modules/kan.py:118, in KANLayer._bsplines_values_at(self, x)
#     115     # Calculate input value for the i-th left knot considering it's distance
#     116     ith_left_bspline_arg = (3 - i) + (x_norm - closest_left_knot)
#     117     ith_left_bspline_value = (
# --> 118         coeff_row[0] * ith_left_bspline_arg.pow(3)
#     119         + coeff_row[1] * ith_left_bspline_arg.pow(2)
#     120         + coeff_row[2] * ith_left_bspline_arg
#     121         + coeff_row[3]
#     122     )
#     123     bsplines_values.scatter_add_(
#     124         dim=2,
#     125         index=ith_left_knot.unsqueeze(-1),
#     126         src=ith_left_bspline_value.unsqueeze(-1),
#     127     )
#     128 return bsplines_values.contiguous()
#
# KeyboardInterrupt:
